# %%
# Import the needed modules.
import numpy as np
import pandas as pd
import sklearn as skl
import tensorflow as tf
# Out:
# WARNING:tensorflow:From C:\Users\Karl_Schultz\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # PART 1: Get and Clean the Telecom Customer Churn Data

# %%
# Read the CSV file into a Pandas DataFrame.
telecom_df = pd.read_csv("Resources/WA_Fn-UseC_-Telco-Customer-Churn.csv") 

# Review the DataFrame.
telecom_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
# Drop the non-useful 'customerID' column.
telecom_df = telecom_df.drop(["customerID"],axis=1)
telecom_df.head(3)
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
#
#   PaperlessBilling     PaymentMethod  MonthlyCharges TotalCharges Churn
# 0              Yes  Electronic check           29.85        29.85    No
# 1               No      Mailed check           56.95       1889.5    No
# 2              Yes      Mailed check           53.85       108.15   Yes

# %%
# Check data types of columns.
# Object type columns will need to be converted to numeric type.
telecom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
#  16  PaymentMethod     7043 non-null   object
#  17  MonthlyCharges    7043 non-null   float64
#  18  TotalCharges      7043 non-null   object
#  19  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
# Replace values in 'Churn' column from "No" and "Yes" to "0" and "1".
# This will turn 'Churn' into an int64 data type.
telecom_cleaned = telecom_df.replace({'Churn': {'No': 0, 'Yes': 1}})

# %%
# Replace empty space string cells with 0 in 'TotalCharges'.
# Preparation to turn this column into numeric data type.
telecom_cleaned = telecom_cleaned.replace({'TotalCharges': {' ': 0}})

# %%
# Change data type of 'TotalCharges' to Float.
telecom_cleaned['TotalCharges'] = telecom_cleaned['TotalCharges'].apply(pd.to_numeric)

# %%
# Check data type of columns to varify changes from cleaning.
telecom_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
#  16  PaymentMethod     7043 non-null   object
#  17  MonthlyCharges    7043 non-null   float64
#  18  TotalCharges      7043 non-null   float64
#  19  Churn             7043 non-null   int64
# dtypes: float64(2), int64(3), object(15)
# memory usage: 1.1+ MB

# %%
# Use 'get_dummies' method to transform categorical columns into boolean columns that can be fed into deep learning model.
telecom_dummies_df = pd.get_dummies(telecom_cleaned)
telecom_dummies_df.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0       1           29.85         29.85      0           True
# 1              0      34           56.95       1889.50      0          False
# 2              0       2           53.85        108.15      1          False
# 3              0      45           42.30       1840.75      0          False
# 4              0       2           70.70        151.65      1           True
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  ...  \
# 0        False       False         True           True  ...
# 1         True        True        False           True  ...
# 2         True        True        False           True  ...
# 3         True        True        False           True  ...
# 4        False        True        False           True  ...
#
#    StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 0                False                     True              False
# 1                False                    False               True
# 2                False                     True              False
# 3                False                    False               True
# 4                False                     True              False
#
#    Contract_Two year  PaperlessBilling_No  PaperlessBilling_Yes  \
# 0              False                False                  True
# 1              False                 True                 False
# 2              False                False                  True
# 3              False                 True                 False
# 4              False                False                  True
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                     True
# 4                                    False
#
#    PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
# 3                                  False                           False
# 4                                  False                            True
#
#    PaymentMethod_Mailed check
# 0                       False
# 1                        True
# 2                        True
# 3                       False
# 4                       False
#
# [5 rows x 46 columns]

# %%
# Save cleaned dataframe to new csv file in "Resources" folder
telecom_dummies_df.to_csv('Resources/telecom_churn_cleaned.csv')

# %% [markdown]
# # PART 2: Split Data into Variables and Features and Train and Test Sets

# %%
# Separate the data into dependent and independent variables.
# Separate the y variable, the dependent variable.
y = telecom_dummies_df.Churn

# Separate the X variable, the independent variables.
X = telecom_dummies_df.drop(columns="Churn")

# %%
# Review the first five data points of y variable Series.
y[:5]
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Churn, dtype: int64

# %%
# Review the first five rows of X variable DataFrame.
X.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Female  \
# 0              0       1           29.85         29.85           True
# 1              0      34           56.95       1889.50          False
# 2              0       2           53.85        108.15          False
# 3              0      45           42.30       1840.75          False
# 4              0       2           70.70        151.65           True
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0        False       False         True           True           False  ...
# 1         True        True        False           True           False  ...
# 2         True        True        False           True           False  ...
# 3         True        True        False           True           False  ...
# 4        False        True        False           True           False  ...
#
#    StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 0                False                     True              False
# 1                False                    False               True
# 2                False                     True              False
# 3                False                    False               True
# 4                False                     True              False
#
#    Contract_Two year  PaperlessBilling_No  PaperlessBilling_Yes  \
# 0              False                False                  True
# 1              False                 True                 False
# 2              False                False                  True
# 3              False                 True                 False
# 4              False                False                  True
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                     True
# 4                                    False
#
#    PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
# 3                                  False                           False
# 4                                  False                            True
#
#    PaymentMethod_Mailed check
# 0                       False
# 1                        True
# 2                        True
# 3                       False
# 4                       False
#
# [5 rows x 45 columns]

# %%
# Check the balance of our target values.
y.value_counts()
# Out:
# Churn
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %%
# Import the train_test_learn module.
from sklearn.model_selection import train_test_split

# Split the data using train_test_split.
# Split data into train and test set using default 75/25 split.
# Assign a random_state of 42 to the function so we can consistently reproduce results.
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Import StandardScaler 
from sklearn.preprocessing import StandardScaler

# Create StandardScaler instances.
scaler = StandardScaler()

# Fit the StandardScaler.
telecom_scaler = scaler.fit(X_train)

# Scale the data.
X_train_scaled = telecom_scaler.transform(X_train)
X_test_scaled = telecom_scaler.transform(X_test)

# %% [markdown]
# # PART 3: Create Tuner To Find Optimal Neural Network Construction for Neural Network Model

# %%
# Create a method that creates a new Sequential model with hyperparameter options.
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function works best for hidden layers.
    activation = hp.Choice('activation',['relu','tanh'])
    
    # Allow kerastuner to decide number of neurons in input layer.
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=30,
        step=5), activation=activation, input_dim=45))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers.
    for i in range(hp.Int('num_layers', 1, 5)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=30,
            step=5),
            activation=activation))
    
    # Use 'sigmoid' activation as predetermined for output layer
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the tuner model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
    
    return nn_model

# %%
# Import the kerastuner library
import keras_tuner as kt

# Instantiate tuner to run through 100 epochs to search for neural network model that is most accurate.
tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=100,
    hyperband_iterations=2)
# Out:
# WARNING:tensorflow:From C:\Users\Karl_Schultz\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Karl_Schultz\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Run the kerastuner and search for best hyperparameters for neural network model.
tuner.search(X_train_scaled,y_train,epochs=100,validation_data=(X_test_scaled,y_test))
# Out:
# Trial 508 Complete [00h 00m 27s]
# val_accuracy: 0.8086314797401428
#
# Best val_accuracy So Far: 0.8177171945571899
# Total elapsed time: 00h 29m 39s

# %%
# Get top 3 model hyperparameters and print the values to use to construct.
top_hyper = tuner.get_best_hyperparameters(3)
for param in top_hyper:
    print(param.values)
# Out:
# {'activation': 'tanh', 'first_units': 1, 'num_layers': 3, 'units_0': 1, 'units_1': 26, 'units_2': 11, 'units_3': 1, 'units_4': 1, 'tuner/epochs': 100, 'tuner/initial_epoch': 34, 'tuner/bracket': 2, 'tuner/round': 2, 'tuner/trial_id': '0228'}
# {'activation': 'relu', 'first_units': 1, 'num_layers': 4, 'units_0': 11, 'units_1': 26, 'units_2': 1, 'units_3': 26, 'units_4': 11, 'tuner/epochs': 100, 'tuner/initial_epoch': 34, 'tuner/bracket': 1, 'tuner/round': 1, 'tuner/trial_id': '0241'}
# {'activation': 'tanh', 'first_units': 6, 'num_layers': 2, 'units_0': 26, 'units_1': 16, 'units_2': 26, 'units_3': 6, 'units_4': 26, 'tuner/epochs': 34, 'tuner/initial_epoch': 12, 'tuner/bracket': 4, 'tuner/round': 3, 'tuner/trial_id': '0387'}

# %%
# Evaluate the accuracy of top 3 models against the test dataset.
top_model = tuner.get_best_models(3)
for model in top_model:
    model_loss, model_accuracy = model.evaluate(X_test_scaled,y_test,verbose=2)
    print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 56/56 - 0s - loss: 0.4107 - accuracy: 0.8177 - 152ms/epoch - 3ms/step
# Loss: 0.4107244908809662, Accuracy: 0.8177171945571899
# 56/56 - 0s - loss: 0.4066 - accuracy: 0.8177 - 163ms/epoch - 3ms/step
# Loss: 0.4065866768360138, Accuracy: 0.8177171945571899
# 56/56 - 0s - loss: 0.4102 - accuracy: 0.8177 - 143ms/epoch - 3ms/step
# Loss: 0.4102018177509308, Accuracy: 0.8177171945571899

# %%
# Display the best model hyperparameters.
# We will be using these below for our deep learning model.
first_hyper = tuner.get_best_hyperparameters(2)[0]
first_hyper.values
# Out:
# {'activation': 'tanh',
#  'first_units': 1,
#  'num_layers': 3,
#  'units_0': 1,
#  'units_1': 26,
#  'units_2': 11,
#  'units_3': 1,
#  'units_4': 1,
#  'tuner/epochs': 100,
#  'tuner/initial_epoch': 34,
#  'tuner/bracket': 2,
#  'tuner/round': 2,
#  'tuner/trial_id': '0228'}

# %% [markdown]
# # PART 4: Create and Validate Deep Leaning Model Based on Recommendations from Tuner

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features_number = 45 # Determined by number of columns in X dataframe
input_layer = 1 # Determined by number of 'num_layers' output of tuner
hidden_layer0 = 1 # Determined by 'units_0' output of tuner
hidden_layer1 = 26 # Determined by 'units_1' output of tuner
hidden_layer2 = 11 # Determined by 'units_2' output of tuner

nn = tf.keras.models.Sequential()

# Input layer
nn.add(
    tf.keras.layers.Dense(units=input_layer, input_dim=input_features_number, activation="tanh") # use 'tanh' for input layer
)

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_layer0, activation="tanh")) # use 'tanh' for hidden layer

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_layer1, activation="tanh")) # use 'tanh' for hidden layer

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_layer2, activation="tanh")) # use 'tanh' for hidden layer

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid")) # use 'sigmoid' for output layer

# Check the structure of the model.
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1)                 46
#
#  dense_5 (Dense)             (None, 1)                 2
#
#  dense_6 (Dense)             (None, 26)                52
#
#  dense_7 (Dense)             (None, 11)                297
#
#  dense_8 (Dense)             (None, 1)                 12
#
# =================================================================
# Total params: 409 (1.60 KB)
# Trainable params: 409 (1.60 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model.
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics = [tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.BinaryAccuracy()])

# %%
# Train the model.
# Run model through 100 epochs.
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 166/166 [==============================] - 1s 859us/step - loss: 0.4226 - precision_5: 0.6432 - recall_5: 0.5446 - binary_accuracy: 0.8006
# Epoch 2/100
# 166/166 [==============================] - 0s 902us/step - loss: 0.4224 - precision_5: 0.6337 - recall_5: 0.5540 - binary_accuracy: 0.7984
# Epoch 3/100
# 166/166 [==============================] - 0s 895us/step - loss: 0.4219 - precision_5: 0.6417 - recall_5: 0.5489 - binary_accuracy: 0.8006
# Epoch 4/100
# 166/166 [==============================] - 0s 907us/step - loss: 0.4221 - precision_5: 0.6344 - recall_5: 0.5381 - binary_accuracy: 0.7969
# Epoch 5/100
# 166/166 [==============================] - 0s 931us/step - loss: 0.4213 - precision_5: 0.6467 - recall_5: 0.5518 - binary_accuracy: 0.8027
# Epoch 6/100
# 166/166 [==============================] - 0s 937us/step - loss: 0.4221 - precision_5: 0.6423 - recall_5: 0.5489 - binary_accuracy: 0.8008
# Epoch 7/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4212 - precision_5: 0.6423 - recall_5: 0.5439 - binary_accuracy: 0.8003
# Epoch 8/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4222 - precision_5: 0.6414 - recall_5: 0.5532 - binary_accuracy: 0.8010
# Epoch 9/100
# 166/166 [==============================] - 0s 923us/step - loss: 0.4216 - precision_5: 0.6433 - recall_5: 0.5475 - binary_accuracy: 0.8010
# Epoch 10/100
# 166/166 [==============================] - 0s 913us/step - loss: 0.4215 - precision_5: 0.6381 - recall_5: 0.5403 - binary_accuracy: 0.7984
# Epoch 11/100
# 166/166 [==============================] - 0s 929us/step - loss: 0.4216 - precision_5: 0.6406 - recall_5: 0.5360 - binary_accuracy: 0.7988
# Epoch 12/100
# 166/166 [==============================] - 0s 907us/step - loss: 0.4211 - precision_5: 0.6374 - recall_5: 0.5439 - binary_accuracy: 0.7986
# Epoch 13/100
# 166/166 [==============================] - 0s 913us/step - loss: 0.4229 - precision_5: 0.6430 - recall_5: 0.5209 - binary_accuracy: 0.7978
# Epoch 14/100
# 166/166 [==============================] - 0s 913us/step - loss: 0.4218 - precision_5: 0.6377 - recall_5: 0.5482 - binary_accuracy: 0.7991
# Epoch 15/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4226 - precision_5: 0.6367 - recall_5: 0.5561 - binary_accuracy: 0.7997
# Epoch 16/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4220 - precision_5: 0.6416 - recall_5: 0.5396 - binary_accuracy: 0.7995
# Epoch 17/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4219 - precision_5: 0.6401 - recall_5: 0.5374 - binary_accuracy: 0.7988
# Epoch 18/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4210 - precision_5: 0.6352 - recall_5: 0.5374 - binary_accuracy: 0.7970
# Epoch 19/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4216 - precision_5: 0.6397 - recall_5: 0.5338 - binary_accuracy: 0.7982
# Epoch 20/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4212 - precision_5: 0.6439 - recall_5: 0.5504 - binary_accuracy: 0.8016
# Epoch 21/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4220 - precision_5: 0.6463 - recall_5: 0.5338 - binary_accuracy: 0.8005
# Epoch 22/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4219 - precision_5: 0.6489 - recall_5: 0.5504 - binary_accuracy: 0.8033
# Epoch 23/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4221 - precision_5: 0.6426 - recall_5: 0.5317 - binary_accuracy: 0.7989
# Epoch 24/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4214 - precision_5: 0.6390 - recall_5: 0.5540 - binary_accuracy: 0.8003
# Epoch 25/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4223 - precision_5: 0.6400 - recall_5: 0.5475 - binary_accuracy: 0.7999
# Epoch 26/100
# 166/166 [==============================] - 0s 898us/step - loss: 0.4210 - precision_5: 0.6378 - recall_5: 0.5396 - binary_accuracy: 0.7982
# Epoch 27/100
# 166/166 [==============================] - 0s 919us/step - loss: 0.4214 - precision_5: 0.6417 - recall_5: 0.5424 - binary_accuracy: 0.7999
# Epoch 28/100
# 166/166 [==============================] - 0s 917us/step - loss: 0.4226 - precision_5: 0.6367 - recall_5: 0.5496 - binary_accuracy: 0.7989
# Epoch 29/100
# 166/166 [==============================] - 0s 951us/step - loss: 0.4214 - precision_5: 0.6433 - recall_5: 0.5410 - binary_accuracy: 0.8003
# Epoch 30/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4226 - precision_5: 0.6467 - recall_5: 0.5360 - binary_accuracy: 0.8008
# Epoch 31/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4215 - precision_5: 0.6399 - recall_5: 0.5496 - binary_accuracy: 0.8001
# Epoch 32/100
# 166/166 [==============================] - 0s 949us/step - loss: 0.4215 - precision_5: 0.6364 - recall_5: 0.5302 - binary_accuracy: 0.7967
# Epoch 33/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4214 - precision_5: 0.6406 - recall_5: 0.5424 - binary_accuracy: 0.7995
# Epoch 34/100
# 166/166 [==============================] - 0s 991us/step - loss: 0.4211 - precision_5: 0.6482 - recall_5: 0.5460 - binary_accuracy: 0.8025
# Epoch 35/100
# 166/166 [==============================] - 0s 916us/step - loss: 0.4221 - precision_5: 0.6343 - recall_5: 0.5453 - binary_accuracy: 0.7976
# Epoch 36/100
# 166/166 [==============================] - 0s 961us/step - loss: 0.4214 - precision_5: 0.6396 - recall_5: 0.5439 - binary_accuracy: 0.7993
# Epoch 37/100
# 166/166 [==============================] - 0s 979us/step - loss: 0.4222 - precision_5: 0.6412 - recall_5: 0.5424 - binary_accuracy: 0.7997
# Epoch 38/100
# 166/166 [==============================] - 0s 982us/step - loss: 0.4214 - precision_5: 0.6425 - recall_5: 0.5417 - binary_accuracy: 0.8001
# Epoch 39/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4219 - precision_5: 0.6473 - recall_5: 0.5518 - binary_accuracy: 0.8029
# Epoch 40/100
# 166/166 [==============================] - 0s 997us/step - loss: 0.4217 - precision_5: 0.6347 - recall_5: 0.5424 - binary_accuracy: 0.7974
# Epoch 41/100
# 166/166 [==============================] - 0s 931us/step - loss: 0.4221 - precision_5: 0.6451 - recall_5: 0.5388 - binary_accuracy: 0.8006
# Epoch 42/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4233 - precision_5: 0.6365 - recall_5: 0.5568 - binary_accuracy: 0.7997
# Epoch 43/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4229 - precision_5: 0.6354 - recall_5: 0.5504 - binary_accuracy: 0.7986
# Epoch 44/100
# 166/166 [==============================] - 0s 949us/step - loss: 0.4218 - precision_5: 0.6455 - recall_5: 0.5345 - binary_accuracy: 0.8003
# Epoch 45/100
# 166/166 [==============================] - 0s 961us/step - loss: 0.4214 - precision_5: 0.6471 - recall_5: 0.5475 - binary_accuracy: 0.8023
# Epoch 46/100
# 166/166 [==============================] - 0s 949us/step - loss: 0.4214 - precision_5: 0.6382 - recall_5: 0.5367 - binary_accuracy: 0.7980
# Epoch 47/100
# 166/166 [==============================] - 0s 927us/step - loss: 0.4220 - precision_5: 0.6353 - recall_5: 0.5489 - binary_accuracy: 0.7984
# Epoch 48/100
# 166/166 [==============================] - 0s 979us/step - loss: 0.4218 - precision_5: 0.6398 - recall_5: 0.5417 - binary_accuracy: 0.7991
# Epoch 49/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4216 - precision_5: 0.6406 - recall_5: 0.5309 - binary_accuracy: 0.7982
# Epoch 50/100
# 166/166 [==============================] - 0s 925us/step - loss: 0.4217 - precision_5: 0.6448 - recall_5: 0.5446 - binary_accuracy: 0.8012
# Epoch 51/100
# 166/166 [==============================] - 0s 907us/step - loss: 0.4220 - precision_5: 0.6419 - recall_5: 0.5532 - binary_accuracy: 0.8012
# Epoch 52/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4218 - precision_5: 0.6413 - recall_5: 0.5338 - binary_accuracy: 0.7988
# Epoch 53/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4218 - precision_5: 0.6376 - recall_5: 0.5417 - binary_accuracy: 0.7984
# Epoch 54/100
# 166/166 [==============================] - 0s 967us/step - loss: 0.4221 - precision_5: 0.6380 - recall_5: 0.5504 - binary_accuracy: 0.7995
# Epoch 55/100
# 166/166 [==============================] - 0s 964us/step - loss: 0.4215 - precision_5: 0.6381 - recall_5: 0.5468 - binary_accuracy: 0.7991
# Epoch 56/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4216 - precision_5: 0.6427 - recall_5: 0.5331 - binary_accuracy: 0.7991
# Epoch 57/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4218 - precision_5: 0.6391 - recall_5: 0.5403 - binary_accuracy: 0.7988
# Epoch 58/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4223 - precision_5: 0.6433 - recall_5: 0.5424 - binary_accuracy: 0.8005
# Epoch 59/100
# 166/166 [==============================] - 0s 913us/step - loss: 0.4215 - precision_5: 0.6399 - recall_5: 0.5446 - binary_accuracy: 0.7995
# Epoch 60/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4214 - precision_5: 0.6367 - recall_5: 0.5396 - binary_accuracy: 0.7978
# Epoch 61/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4212 - precision_5: 0.6416 - recall_5: 0.5410 - binary_accuracy: 0.7997
# Epoch 62/100
# 166/166 [==============================] - 0s 919us/step - loss: 0.4214 - precision_5: 0.6430 - recall_5: 0.5482 - binary_accuracy: 0.8010
# Epoch 63/100
# 166/166 [==============================] - 0s 923us/step - loss: 0.4221 - precision_5: 0.6498 - recall_5: 0.5353 - binary_accuracy: 0.8018
# Epoch 64/100
# 166/166 [==============================] - 0s 979us/step - loss: 0.4229 - precision_5: 0.6362 - recall_5: 0.5410 - binary_accuracy: 0.7978
# Epoch 65/100
# 166/166 [==============================] - 0s 929us/step - loss: 0.4220 - precision_5: 0.6450 - recall_5: 0.5424 - binary_accuracy: 0.8010
# Epoch 66/100
# 166/166 [==============================] - 0s 950us/step - loss: 0.4213 - precision_5: 0.6401 - recall_5: 0.5424 - binary_accuracy: 0.7993
# Epoch 67/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4211 - precision_5: 0.6370 - recall_5: 0.5403 - binary_accuracy: 0.7980
# Epoch 68/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4218 - precision_5: 0.6426 - recall_5: 0.5446 - binary_accuracy: 0.8005
# Epoch 69/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4216 - precision_5: 0.6334 - recall_5: 0.5482 - binary_accuracy: 0.7976
# Epoch 70/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4230 - precision_5: 0.6438 - recall_5: 0.5410 - binary_accuracy: 0.8005
# Epoch 71/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4209 - precision_5: 0.6388 - recall_5: 0.5496 - binary_accuracy: 0.7997
# Epoch 72/100
# 166/166 [==============================] - 0s 943us/step - loss: 0.4216 - precision_5: 0.6327 - recall_5: 0.5576 - binary_accuracy: 0.7984
# Epoch 73/100
# 166/166 [==============================] - 0s 973us/step - loss: 0.4212 - precision_5: 0.6424 - recall_5: 0.5532 - binary_accuracy: 0.8014
# Epoch 74/100
# 166/166 [==============================] - 0s 931us/step - loss: 0.4203 - precision_5: 0.6518 - recall_5: 0.5360 - binary_accuracy: 0.8025
# Epoch 75/100
# 166/166 [==============================] - 0s 962us/step - loss: 0.4222 - precision_5: 0.6400 - recall_5: 0.5576 - binary_accuracy: 0.8010
# Epoch 76/100
# 166/166 [==============================] - 0s 913us/step - loss: 0.4213 - precision_5: 0.6361 - recall_5: 0.5496 - binary_accuracy: 0.7988
# Epoch 77/100
# 166/166 [==============================] - 0s 991us/step - loss: 0.4216 - precision_5: 0.6468 - recall_5: 0.5532 - binary_accuracy: 0.8029
# Epoch 78/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4217 - precision_5: 0.6464 - recall_5: 0.5432 - binary_accuracy: 0.8016
# Epoch 79/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4218 - precision_5: 0.6402 - recall_5: 0.5504 - binary_accuracy: 0.8003
# Epoch 80/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4218 - precision_5: 0.6529 - recall_5: 0.5468 - binary_accuracy: 0.8042
# Epoch 81/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4209 - precision_5: 0.6405 - recall_5: 0.5525 - binary_accuracy: 0.8006
# Epoch 82/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4221 - precision_5: 0.6416 - recall_5: 0.5410 - binary_accuracy: 0.7997
# Epoch 83/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4213 - precision_5: 0.6371 - recall_5: 0.5482 - binary_accuracy: 0.7989
# Epoch 84/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4217 - precision_5: 0.6421 - recall_5: 0.5446 - binary_accuracy: 0.8003
# Epoch 85/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4214 - precision_5: 0.6481 - recall_5: 0.5525 - binary_accuracy: 0.8033
# Epoch 86/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4218 - precision_5: 0.6407 - recall_5: 0.5619 - binary_accuracy: 0.8018
# Epoch 87/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4220 - precision_5: 0.6564 - recall_5: 0.5360 - binary_accuracy: 0.8041
# Epoch 88/100
# 166/166 [==============================] - 0s 943us/step - loss: 0.4218 - precision_5: 0.6341 - recall_5: 0.5410 - binary_accuracy: 0.7970
# Epoch 89/100
# 166/166 [==============================] - 0s 964us/step - loss: 0.4219 - precision_5: 0.6365 - recall_5: 0.5518 - binary_accuracy: 0.7991
# Epoch 90/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4227 - precision_5: 0.6317 - recall_5: 0.5540 - binary_accuracy: 0.7976
# Epoch 91/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4216 - precision_5: 0.6486 - recall_5: 0.5353 - binary_accuracy: 0.8014
# Epoch 92/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4215 - precision_5: 0.6444 - recall_5: 0.5554 - binary_accuracy: 0.8023
# Epoch 93/100
# 166/166 [==============================] - 0s 980us/step - loss: 0.4213 - precision_5: 0.6407 - recall_5: 0.5453 - binary_accuracy: 0.7999
# Epoch 94/100
# 166/166 [==============================] - 0s 940us/step - loss: 0.4222 - precision_5: 0.6387 - recall_5: 0.5532 - binary_accuracy: 0.8001
# Epoch 95/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4212 - precision_5: 0.6406 - recall_5: 0.5489 - binary_accuracy: 0.8003
# Epoch 96/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4215 - precision_5: 0.6365 - recall_5: 0.5417 - binary_accuracy: 0.7980
# Epoch 97/100
# 166/166 [==============================] - 0s 931us/step - loss: 0.4210 - precision_5: 0.6364 - recall_5: 0.5504 - binary_accuracy: 0.7989
# Epoch 98/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4229 - precision_5: 0.6441 - recall_5: 0.5338 - binary_accuracy: 0.7997
# Epoch 99/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4209 - precision_5: 0.6482 - recall_5: 0.5460 - binary_accuracy: 0.8025
# Epoch 100/100
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4219 - precision_5: 0.6400 - recall_5: 0.5460 - binary_accuracy: 0.7997

# %%
#Evaluate the model for accuracy using the test data.
model_loss, model_precision, model_recall, model_binary_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Precision: {model_precision}, Recall: {model_recall}, Accuracy: {model_binary_accuracy}")
# Out:
# 56/56 - 0s - loss: 0.4071 - precision_3: 0.6814 - recall_3: 0.5804 - binary_accuracy: 0.8120 - 211ms/epoch - 4ms/step
# Loss: 0.4071129262447357, Precision: 0.6813725233078003, Recall: 0.5803757905960083, Accuracy: 0.8120386004447937

# %%
# Manually calculate F1 Score
print(2*(model_binary_accuracy*model_recall)/(model_binary_accuracy+model_recall))
# Out:
# 0.6769357567115422

# %%
# Export neural network model to keras file
nn.save("Resources/Telecom_Churn_Model.keras")
